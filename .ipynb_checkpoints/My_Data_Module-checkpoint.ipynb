# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import numpy as np
import math

def load_data(x, y):
    #x will represent the first experiment data MatLab file and y will represent the second experiment data
    v2 = loadmat(x)
    v2_2 = loadmat(y)
    print("Type of file:")
    print(type(v2))
    print()
    print("Dictionary files:")
    print(dict.keys(v2))
    return (v2, v2_2); 

exp1 = 'data/NR-z0131.ezrev4.001.p1.mat'
exp2 = 'data/NR-z0126.ezrev4.002.p1.mat'
v2, v2_2 = load_data(exp1, exp2)


#np.set_printoptions(threshold = 99999999)
np.set_printoptions(threshold=10)
# Out:
# Type of file:
# <class 'dict'>
#
# Dictionary files:
# dict_keys(['__header__', '__version__', '__globals__', 'matfile', 'fext', 'outpath', 'smoothspikes', 'plxfn', 'chanid', 'unitid', 'psth', 'rnz', 'trialcount', 'freps', 'shortstimlist', 'kHzdata', 'sid', 'ypos', 'xpos', 'r', 'fpath', 'refreshperframe', 'spiketime', 'eyepos', 'droptime', 'phototime', 'stimtime', 'flist', 'h', 's'])

# %%
st = v2.get('spiketime')
st_2 = v2_2.get('spiketime')
#print(st[0][0])
#plt.plot(st)

tc = v2.get('trialcount')
tc2 = v2_2.get('trialcount')
#there are 28 trials, use this to relate to other variables in a function

stimt = v2.get('stimtime')
pt = v2.get('phototime')
pt_2 = v2_2.get('phototime')

print("PhotoTime (Stimulus) Array:")
print(len(pt))
#print(pt_2[:, 1])
print(pt)
print()

print("SpikeTime Array:")
print(len(st))
print(st)
print()

#print("Stimtime Array:")
#print(len(stimt))
#print(stimt)
print()

fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(9, 6))
plt.xlabel('Trial Number')
plt.ylabel('Response')
plt.title('Experiment 1')
axes[0].plot(pt[:,0],pt[:,1], color='blue')
axes[1].plot(st[:,0],st[:,1], color='red')

fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(9, 6))
plt.title('Experiment 2')
plt.xlabel('Trial Number')
plt.ylabel('Response')
axes[0].plot(pt_2[:,0],pt_2[:,1], color='blue')
axes[1].plot(st_2[:,0],st_2[:,1], color='red')
# Out:
# PhotoTime (Stimulus) Array:
# 4286
# [[   1 1825]
#  [   1 2891]
#  [   1 2925]
#  ...
#  [  28 7112]
#  [  28 7145]
#  [  29  713]]
#
# SpikeTime Array:
# 1060
# [[   1 1825]
#  [   1 1880]
#  [   1 2214]
#  ...
#  [  28 7201]
#  [  28 7231]
#  [  29  713]]

# %%
import pandas as pd
pan_pt = pd.DataFrame(pt, columns=["trial", "response"])
pan_pt = pan_pt.set_index(['trial'])

pan_pt2 = pd.DataFrame(pt_2, columns=["trial", "response"])
pan_pt2 = pan_pt2.set_index(['trial'])

pan_st = pd.DataFrame(st, columns=["trial", "response"])
pan_st = pan_st.set_index(['trial'])

pan_st2 = pd.DataFrame(st_2, columns=["trial", "response"])
pan_st2 = pan_st2.set_index(['trial'])

#This section is to calculate statistics within trials
#The for loop used is repeated for both experiment 1 and 2 as the same logic applies
#Only difference was that different variable names had to be used to represent different values when printing

print("Difference in Stimulus and Response Within Trials in Experiment 1")
print("*** where difference = stimulus - response ***")
print()

exp1mean = []
exp1max = []
exp1std = []
exp2mean = []
exp2max = []
exp2std = []

for trial in set(pan_pt.index.values) and set(pan_st.index.values):
    print("Exp1 Trial Number: ", trial)
    pmean = pan_pt.loc[trial].mean().item()
    smean = pan_st.loc[trial].mean().item()
    pmax = pan_pt.loc[trial].max().item()
    smax = pan_st.loc[trial].max().item()
    pstd = pan_pt.loc[trial].std().item()
    sstd = pan_st.loc[trial].std().item()
    dmean = pmean - smean
    dmax = pmax - smax
    dstd = pstd - sstd
    print("Difference in Mean: ", (dmean))
    print("Difference in Max: ", (dmax))
    print("Difference in Standard Deviation: ", (dstd))
    exp1mean.append(dmean)
    exp1max.append(dmax)
    exp1std.append(dstd)
    print()
    
print("****************************************************") 
print("****************************************************")    
print("****************************************************")    

#Start of Experiment 2 (printed stars used to visually seperate data)

print("Difference in Stimulus and Response Within Trials in Experiment 2")
print("*** where difference = stimulus - response ***")
print()

for trial in set(pan_pt2.index.values) and set(pan_st2.index.values):
    print("Exp2 Trial Number: ", trial)
    pmean2 = pan_pt2.loc[trial].mean().item()
    smean2 = pan_st2.loc[trial].mean().item()
    pmax2 = pan_pt2.loc[trial].max().item()
    smax2 = pan_st2.loc[trial].max().item()
    pstd2 = pan_pt2.loc[trial].std().item()
    sstd2 = pan_st2.loc[trial].std().item()
    dmean2 = pmean2 - smean2
    dmax2 = pmax2 - smax2
    dstd2 = pstd2 - sstd2
    print("Difference in Mean: ", dmean2)
    print("Difference in Max: ", dmax2)
    print("Difference in Standard Deviation: ", dstd2)
    exp2mean.append(dmean2)
    exp2max.append(dmax2)
    exp2std.append(dstd2)
    print()
    
print("****************************************************")
print("****************************************************")
print("****************************************************")

#These next two sections represent the statistics that were used to compare data across trials
#Essentially statistics on the 'stimulus' and 'response' data itself
#Because no iteration was required, I was able to print the basic operational functions with no for loops

print("Difference Across Trials in Experiment 1")
print()

print("Total Trial Count: ", tc)
print()

print("Mean Value for Stimulus: ", pt[:, 1].mean())
print("Max Value for Stimulus: ", pt[:, 1].max())
print("Standard Deviation for Stimulus: ", pt[:, 1].std())
print()
print("Mean Value for Neuron Response: ", st[:, 1].mean())
print("Max Value for Neuron Response: ", st[:, 1].max())
print("Standard Deviation for Neuron Response: ", st[:, 1].std())
print()
print("Difference of Means: ", (pt[:, 1].mean())-(st[:, 1].mean()))
print("Difference of Max: ", (pt[:, 1].max())-(st[:, 1].max()))
print("Difference of Standard Deviations: ", (pt[:, 1].std())-(st[:, 1].std()))

print()
print("****************************************************")
print("****************************************************")
print("****************************************************")

print("Difference Across Trials in Experiment 2")
print()

print("Total Trial Count: ", tc2)
print()

print("Mean Value for Stimulus: ", pt_2[:, 1].mean())
print("Max Value for Stimulus: ", pt_2[:, 1].max())
print("Standard Deviation for Stimulus: ", pt_2[:, 1].std())
print()
print("Mean Value for Neuron Response: ", st_2[:, 1].mean())
print("Max Value for Neuron Response: ", st_2[:, 1].max())
print("Standard Deviation for Neuron Response: ", st_2[:, 1].std())
print()
print("Difference of Means: ", (pt_2[:, 1].mean())-(st_2[:, 1].mean()))
print("Difference of Max: ", (pt_2[:, 1].max())-(st_2[:, 1].max()))
print("Difference of Standard Deviations: ", (pt_2[:, 1].std())-(st_2[:, 1].std()))
# Out:
# Difference in Stimulus and Response Within Trials in Experiment 1
# *** where difference = stimulus - response ***
#
# Exp1 Trial Number:  1
# Difference in Mean:  402.84381408065656
# Difference in Max:  8
# Difference in Standard Deviation:  -405.8782708901665
#
# Exp1 Trial Number:  2
# Difference in Mean:  -28.13952827507819
# Difference in Max:  -96
# Difference in Standard Deviation:  -312.65234153572214
#
# Exp1 Trial Number:  3
# Difference in Mean:  167.58600350709366
# Difference in Max:  135
# Difference in Standard Deviation:  -163.1895360937583
#
# Exp1 Trial Number:  4
# Difference in Mean:  303.2129342965254
# Difference in Max:  239
# Difference in Standard Deviation:  -87.76344803227198
#
# Exp1 Trial Number:  5
# Difference in Mean:  289.48217468805706
# Difference in Max:  -33
# Difference in Standard Deviation:  -264.4431949050022
#
# Exp1 Trial Number:  6
# Difference in Mean:  37.45751633986947
# Difference in Max:  15
# Difference in Standard Deviation:  -179.4084715860522
#
# Exp1 Trial Number:  7
# Difference in Mean:  628.4444444444443
# Difference in Max:  -52
# Difference in Standard Deviation:  -133.64438593356226
#
# Exp1 Trial Number:  8
# Difference in Mean:  733.6339869281046
# Difference in Max:  -16
# Difference in Standard Deviation:  -528.997817804838
#
# Exp1 Trial Number:  9
# Difference in Mean:  382.3562091503263
# Difference in Max:  35
# Difference in Standard Deviation:  -170.58024845407476
#
# Exp1 Trial Number:  10
# Difference in Mean:  573.8701410388712
# Difference in Max:  36
# Difference in Standard Deviation:  -314.1911160078448
#
# Exp1 Trial Number:  11
# Difference in Mean:  191.01429738562092
# Difference in Max:  -48
# Difference in Standard Deviation:  -234.7968072872602
#
# Exp1 Trial Number:  12
# Difference in Mean:  186.0078431372549
# Difference in Max:  14
# Difference in Standard Deviation:  -338.21395739775903
#
# Exp1 Trial Number:  13
# Difference in Mean:  772.8448572411417
# Difference in Max:  89
# Difference in Standard Deviation:  -531.3040222473189
#
# Exp1 Trial Number:  14
# Difference in Mean:  475.8812889496885
# Difference in Max:  87
# Difference in Standard Deviation:  -363.35433026131227
#
# Exp1 Trial Number:  15
# Difference in Mean:  569.94360410831
# Difference in Max:  -7
# Difference in Standard Deviation:  -349.593906938032
#
# Exp1 Trial Number:  16
# Difference in Mean:  599.7764705882355
# Difference in Max:  43
# Difference in Standard Deviation:  -214.26039627983687
#
# Exp1 Trial Number:  17
# Difference in Mean:  326.0141260805394
# Difference in Max:  100
# Difference in Standard Deviation:  -326.28121664360697
#
# Exp1 Trial Number:  18
# Difference in Mean:  244.21464646464665
# Difference in Max:  46
# Difference in Standard Deviation:  -428.38366164557874
#
# Exp1 Trial Number:  19
# Difference in Mean:  93.34824346405185
# Difference in Max:  213
# Difference in Standard Deviation:  -376.8161380802194
#
# Exp1 Trial Number:  20
# Difference in Mean:  48.901960784313815
# Difference in Max:  41
# Difference in Standard Deviation:  -204.38541863355658
#
# Exp1 Trial Number:  21
# Difference in Mean:  -96.59988633134344
# Difference in Max:  199
# Difference in Standard Deviation:  -113.82806574633082
#
# Exp1 Trial Number:  22
# Difference in Mean:  120.52287581699329
# Difference in Max:  -49
# Difference in Standard Deviation:  -224.59294458884028
#
# Exp1 Trial Number:  23
# Difference in Mean:  411.16059757236235
# Difference in Max:  658
# Difference in Standard Deviation:  -59.30199754762725
#
# Exp1 Trial Number:  24
# Difference in Mean:  -168.6489262371615
# Difference in Max:  -388
# Difference in Standard Deviation:  -331.4881947153401
#
# Exp1 Trial Number:  25
# Difference in Mean:  242.20261437908448
# Difference in Max:  -16
# Difference in Standard Deviation:  -326.5356178113725
#
# Exp1 Trial Number:  26
# Difference in Mean:  979.3888888888887
# Difference in Max:  299
# Difference in Standard Deviation:  -338.78691567907845
#
# Exp1 Trial Number:  27
# Difference in Mean:  -198.28289473684254
# Difference in Max:  -31
# Difference in Standard Deviation:  -400.7182663287506
#
# Exp1 Trial Number:  28
# Difference in Mean:  149.10192545486734
# Difference in Max:  -86
# Difference in Standard Deviation:  -360.7498992906692
#
# Exp1 Trial Number:  29
# Difference in Mean:  0.0
# Difference in Max:  0
# Difference in Standard Deviation:  nan
#
# ****************************************************
# ****************************************************
# ****************************************************
# Difference in Stimulus and Response Within Trials in Experiment 2
# *** where difference = stimulus - response ***
#
# Exp2 Trial Number:  1
# Difference in Mean:  1.6213894159818665
# Difference in Max:  -68
# Difference in Standard Deviation:  -86.79590743484141
#
# Exp2 Trial Number:  2
# Difference in Mean:  -105.88208507446689
# Difference in Max:  53
# Difference in Standard Deviation:  -31.589874573556926
#
# Exp2 Trial Number:  3
# Difference in Mean:  -129.93236461251217
# Difference in Max:  -407
# Difference in Standard Deviation:  -2.5395104432921016
#
# Exp2 Trial Number:  4
# Difference in Mean:  -133.93498452012363
# Difference in Max:  -19
# Difference in Standard Deviation:  -29.553445747464366
#
# Exp2 Trial Number:  5
# Difference in Mean:  21.270444135659545
# Difference in Max:  -481
# Difference in Standard Deviation:  -168.8047452724818
#
# Exp2 Trial Number:  6
# Difference in Mean:  5.335276452923608
# Difference in Max:  -87
# Difference in Standard Deviation:  -50.379797118533816
#
# Exp2 Trial Number:  7
# Difference in Mean:  24.895833333333258
# Difference in Max:  9
# Difference in Standard Deviation:  -42.08442491891344
#
# Exp2 Trial Number:  8
# Difference in Mean:  354.0625
# Difference in Max:  12
# Difference in Standard Deviation:  -195.7428853476029
#
# Exp2 Trial Number:  9
# Difference in Mean:  9.600871459695554
# Difference in Max:  -284
# Difference in Standard Deviation:  -96.63762415844371
#
# Exp2 Trial Number:  10
# Difference in Mean:  30.3240690478774
# Difference in Max:  -350
# Difference in Standard Deviation:  -53.56333776084807
#
# Exp2 Trial Number:  11
# Difference in Mean:  -47.49939267742502
# Difference in Max:  -34
# Difference in Standard Deviation:  -146.14189113163638
#
# Exp2 Trial Number:  12
# Difference in Mean:  72.53378824565289
# Difference in Max:  -335
# Difference in Standard Deviation:  -63.24352129992781
#
# Exp2 Trial Number:  13
# Difference in Mean:  69.83676072054823
# Difference in Max:  -359
# Difference in Standard Deviation:  -22.153765546851673
#
# Exp2 Trial Number:  14
# Difference in Mean:  -249.47117754205465
# Difference in Max:  -58
# Difference in Standard Deviation:  -111.21641118873526
#
# Exp2 Trial Number:  15
# Difference in Mean:  72.80179028132989
# Difference in Max:  -309
# Difference in Standard Deviation:  -117.88042910059835
#
# Exp2 Trial Number:  16
# Difference in Mean:  58.54209666322686
# Difference in Max:  -76
# Difference in Standard Deviation:  -81.58642259707221
#
# Exp2 Trial Number:  17
# Difference in Mean:  -7.416490019430967
# Difference in Max:  -80
# Difference in Standard Deviation:  -131.71125028815186
#
# Exp2 Trial Number:  18
# Difference in Mean:  40.465617116696194
# Difference in Max:  -772
# Difference in Standard Deviation:  -47.22281665699052
#
# Exp2 Trial Number:  19
# Difference in Mean:  -68.95676219205643
# Difference in Max:  -112
# Difference in Standard Deviation:  -0.922997457866586
#
# Exp2 Trial Number:  20
# Difference in Mean:  -17.246071938709065
# Difference in Max:  -57
# Difference in Standard Deviation:  -121.61896651815846
#
# Exp2 Trial Number:  21
# Difference in Mean:  -128.88601837131228
# Difference in Max:  -617
# Difference in Standard Deviation:  -67.84928396174155
#
# Exp2 Trial Number:  22
# Difference in Mean:  0.5449346405225697
# Difference in Max:  -683
# Difference in Standard Deviation:  -140.92550003695033
#
# Exp2 Trial Number:  23
# Difference in Mean:  10.310457516339739
# Difference in Max:  -75
# Difference in Standard Deviation:  28.3693896274292
#
# Exp2 Trial Number:  24
# Difference in Mean:  -73.26583966920089
# Difference in Max:  7
# Difference in Standard Deviation:  11.468155916289106
#
# Exp2 Trial Number:  25
# Difference in Mean:  23.543209876543187
# Difference in Max:  -338
# Difference in Standard Deviation:  48.326670434732705
#
# Exp2 Trial Number:  26
# Difference in Mean:  -5.816879237972444
# Difference in Max:  -128
# Difference in Standard Deviation:  -84.81749046228651
#
# Exp2 Trial Number:  27
# Difference in Mean:  -4.745052963713533
# Difference in Max:  -408
# Difference in Standard Deviation:  -83.46184403071311
#
# Exp2 Trial Number:  28
# Difference in Mean:  194.10375816993474
# Difference in Max:  -65
# Difference in Standard Deviation:  -33.727163951411285
#
# Exp2 Trial Number:  29
# Difference in Mean:  190.71258169934572
# Difference in Max:  -79
# Difference in Standard Deviation:  -179.68500613446417
#
# Exp2 Trial Number:  30
# Difference in Mean:  -93.6568627450979
# Difference in Max:  -481
# Difference in Standard Deviation:  -119.79045569679079
#
# Exp2 Trial Number:  31
# Difference in Mean:  60.28252161079536
# Difference in Max:  -31
# Difference in Standard Deviation:  -21.572642002440034
#
# Exp2 Trial Number:  32
# Difference in Mean:  47.8387096774195
# Difference in Max:  -524
# Difference in Standard Deviation:  -132.51361598197877
#
# Exp2 Trial Number:  33
# Difference in Mean:  -5.494517366175387
# Difference in Max:  2
# Difference in Standard Deviation:  -23.74942135235301
#
# Exp2 Trial Number:  34
# Difference in Mean:  -79.67389303139089
# Difference in Max:  -60
# Difference in Standard Deviation:  -19.82190525172632
#
# Exp2 Trial Number:  35
# Difference in Mean:  -115.63169934640518
# Difference in Max:  -383
# Difference in Standard Deviation:  -167.52541407115677
#
# Exp2 Trial Number:  36
# Difference in Mean:  -119.5
# Difference in Max:  -239
# Difference in Standard Deviation:  nan
#
# Exp2 Trial Number:  37
# Difference in Mean:  103.26263838868908
# Difference in Max:  -68
# Difference in Standard Deviation:  -94.98178931178904
#
# Exp2 Trial Number:  38
# Difference in Mean:  -249.85933141834266
# Difference in Max:  -55
# Difference in Standard Deviation:  19.827113622544175
#
# Exp2 Trial Number:  39
# Difference in Mean:  44.18272440870851
# Difference in Max:  -80
# Difference in Standard Deviation:  -39.897916369404356
#
# ****************************************************
# ****************************************************
# ****************************************************
# Difference Across Trials in Experiment 1
#
# Total Trial Count:  [[28]]
#
# Mean Value for Stimulus:  5496.309846010266
# Max Value for Stimulus:  9339
# Standard Deviation for Stimulus:  1722.591394415666
#
# Mean Value for Neuron Response:  5176.500943396227
# Max Value for Neuron Response:  9249
# Standard Deviation for Neuron Response:  1942.7038337966408
#
# Difference of Means:  319.80890261403874
# Difference of Max:  90
# Difference of Standard Deviations:  -220.11243938097482
#
# ****************************************************
# ****************************************************
# ****************************************************
# Difference Across Trials in Experiment 2
#
# Total Trial Count:  [[38]]
#
# Mean Value for Stimulus:  4103.726747336103
# Max Value for Stimulus:  7692
# Standard Deviation for Stimulus:  1508.6132763638348
#
# Mean Value for Neuron Response:  4108.054954034729
# Max Value for Neuron Response:  7639
# Standard Deviation for Neuron Response:  1577.1677196731591
#
# Difference of Means:  -4.328206698626673
# Difference of Max:  53
# Difference of Standard Deviations:  -68.55444330932437

# %%
#Setting data variables
data2plot_mean = [exp1mean, exp2mean]
data2plot_max = [exp1max, exp2max]
data2plot_std = [exp1std, exp2std]

#Plotting Mean Boxplot
plt.title("Difference in Mean Within Trials")
plt.xlabel('Experiment')
plt.ylabel('Difference in Mean Intensity (Stimulus - Response)')
plt.boxplot(data2plot_mean)
plt.axhline((pt[:, 1].mean())-(st[:, 1].mean()), label='Exp1 across trials', color='blue')
plt.axhline((pt_2[:, 1].mean())-(st_2[:, 1].mean()), label='Exp2 across trials', color='red')
plt.legend(loc='upper right')

# %%
#Plotting Max Boxplot
plt.title("Difference in Max Within Trials")
plt.xlabel('Experiment')
plt.ylabel('Difference in Max Intensity (S - R)')
plt.boxplot(data2plot_max)
plt.axhline((pt[:, 1].max())-(st[:, 1].max()), label='Exp1 across trials', color='blue')
plt.axhline((pt_2[:, 1].max())-(st_2[:, 1].max()), label='Exp2 across trials', color='red')
plt.legend(loc='upper right')

# %%
#Ploting Std Boxplot
plt.title("Difference in Standard Deviation Within Trials")
plt.xlabel('Intensity (Blue = Exp1)(Orange = Exp2)')
plt.ylabel('Count')
plt.hist(data2plot_std, bins = 10)
plt.vlines((pt[:, 1].std())-(st[:, 1].std()), 0, 14, label='Exp1 across trials', color='red')
plt.vlines((pt_2[:, 1].std())-(st_2[:, 1].std()), 0, 14, label='Exp2 across trials', color='green')
plt.legend(loc='upper left')
